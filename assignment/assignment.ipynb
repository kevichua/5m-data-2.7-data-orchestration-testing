# %% [markdown]
# # Assignment

# %% [markdown]
# ## Brief
#
# Write the YML for the following questions.

# %% [markdown]
# ## Instructions
#
# Paste the answer as YML in the answer code section below each question.

# %% [markdown]
# ### Question 1
#
# Question: Add 2 more tests each using `dbt_utils` and `dbt-expectations` to `fact_sales`.
#
# Answer:
#
# Specs for `dbt_utils`:
#
# ```yml
#
# ```
#
# Specs for `dbt-expectations`:
#
# ```yml

# %%
# Specs for dbt_utils
models:
  - name: fact_sales
    tests:
      - dbt_utils.expression_is_true:
          expression: "sale_dollars >= 0"
      - dbt_utils.expression_is_true:
          expression: "state_bottle_retail >= state_bottle_cost"
# Out:
#   Cell In[4], line 2
#     models:
#            ^
# SyntaxError: invalid syntax

# %%
# Specs for dbt-expectations

models:
  - name: fact_sales
    columns:
      - name: bottles_sold
        tests:
          - dbt_expectations.expect_column_values_to_be_between:
              min_value: 0
              max_value: 15000
      - name: sale_dollars
        tests:
          - dbt_expectations.expect_column_values_to_not_be_null
# Out:
#   Cell In[5], line 3
#     models:
#            ^
# SyntaxError: invalid syntax
